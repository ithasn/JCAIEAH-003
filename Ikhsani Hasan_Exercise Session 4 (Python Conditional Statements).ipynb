# %% [markdown]
# # Soal 1:

# %%
angka = input('Masukkan angka: ')

if angka.isdigit():
    angka = int(angka)
    if angka % 2 == 0:
        print(f'Angka {angka} tergolong bilangan GENAP')
    else:
        print(f'Angka {angka} tergolong bilangan GANJIL')
else:
    print('Masukkan bilangan bulat')
# Out:
# Angka 3 tergolong bilangan GANJIL

# %% [markdown]
# ___

# %% [markdown]
# # Soal 2:

# %%
massa = float(input('Masukkan Massa (kg): '))
tinggi = float(input('Masukkan Tinggi (cm): '))

IMT = massa / ((tinggi/100)**2)

print(f'Massa {massa} Kg dan tinggi {tinggi/100} m')

if IMT < 18.5:
    print(f'IMT = {IMT}, BERAT BADAN KURANG!')
elif IMT >= 18.5 and IMT < 25:
    print(f'IMT = {IMT}, BERAT BADAN IDEAL!')
elif IMT >= 25 and IMT < 30:
    print(f'IMT = {IMT}, BERAT BADAN BERLEBIH!')
elif IMT >= 30 and IMT < 40:
    print(f'IMT = {IMT}, BERAT BADAN SANGAT BERLEBIH!')
elif IMT >= 40:
    print(f'IMT = {IMT}, OBESITAS!')
else:
    print('Error')
# Out:
# Massa 65.0 Kg dan tinggi 1.6580000000000001 m
# IMT = 23.645271454991768, BERAT BADAN IDEAL!

# %% [markdown]
# ___

# %% [markdown]
# # Soal 3:

# %%
hargaApel = 10_000
hargaJeruk = 15_000
hargaAnggur = 20_000

qtyApel = int(input('Masukkan Jumlah Apel: '))
print(f'Jumlah Apel = {qtyApel}')

qtyJeruk = int(input('Masukkan Jumlah Jeruk: '))
print(f'Jumlah Jeruk = {qtyJeruk}')

qtyAnggur = int(input('Masukkan Jumlah Anggur: '))
print(f'Jumlah Anggur = {qtyAnggur}')

totalApel = qtyApel * hargaApel
totalJeruk = qtyJeruk * hargaJeruk
totalAnggur = qtyAnggur * hargaAnggur
totalSemua = totalApel + totalJeruk + totalAnggur

print('\nDetail Belanja\n')

print(f'Apel : {qtyApel} x {hargaApel} = {totalApel}')
print(f'Jeruk : {qtyJeruk} x {hargaJeruk} = {totalJeruk}')
print(f'Anggur : {qtyAnggur} x {hargaAnggur} = {totalAnggur}')

print(f'\nTotal : {totalSemua}')

jumlahBayar = int(input('Masukkan jumlah uang: '))

print(f'\nJumlah uang: {jumlahBayar}')

selisihBayar = jumlahBayar - totalSemua

if selisihBayar < 0:
    print('Transaksi anda dibatalkan')
    print(f'Uangnya kurang sebesar {-selisihBayar}')
elif selisihBayar == 0:
    print('Terima kasih')
else:
    print('Terima kasih')
    print(f'Uang kembali anda: {selisihBayar}')
# Out:
# Jumlah Apel = 3
# Jumlah Jeruk = 2
# Jumlah Anggur = 5
#
# Detail Belanja
#
# Apel : 3 x 10000 = 30000
# Jeruk : 2 x 15000 = 30000
# Anggur : 5 x 20000 = 100000
#
# Total : 160000
#
# Jumlah uang: 175000
# Terima kasih
# Uang kembali anda: 15000
